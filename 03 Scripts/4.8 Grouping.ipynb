# %% [markdown]
# # import

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # path to string

# %%
path = r'C:\Users\leevg\OneDrive\Desktop\CF\DI\A4\03-2022 Instacart Basket Analysis'

# %% [markdown]
# # import data

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head(10)
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
# 5           5   3367565        1             6                   2
# 6           6    550135        1             7                   1
# 7           7   3108588        1             8                   1
# 8           8   2295261        1             9                   1
# 9           9   2550362        1            10                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
# 5                  7                    19.0         196                  1
# 6                  9                    20.0         196                  1
# 7                 14                    14.0         196                  2
# 8                 16                     0.0         196                  4
# 9                  8                    30.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
# 5          1         Soda        77              7     9.0   both
# 6          1         Soda        77              7     9.0   both
# 7          1         Soda        77              7     9.0   both
# 8          1         Soda        77              7     9.0   both
# 9          1         Soda        77              7     9.0   both
#
#       busiest_day busiest_period_of_day
# 0  Regularly busy        Average orders
# 1    Slowest days        Average orders
# 2    Slowest days        Average orders
# 3    Slowest days        Average orders
# 4    Slowest days        Average orders
# 5  Regularly busy        Average orders
# 6    Busiest days        Average orders
# 7    Busiest days        Average orders
# 8    Busiest days        Average orders
# 9    Slowest days        Average orders

# %%
df = df.drop(columns = 'Unnamed: 0')

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both    Slowest days
# 2         Soda        77              7     9.0   both    Slowest days
# 3         Soda        77              7     9.0   both    Slowest days
# 4         Soda        77              7     9.0   both    Slowest days
# 5         Soda        77              7     9.0   both  Regularly busy
# 6         Soda        77              7     9.0   both    Busiest days
# 7         Soda        77              7     9.0   both    Busiest days
# 8         Soda        77              7     9.0   both    Busiest days
# 9         Soda        77              7     9.0   both    Slowest days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2        Average orders
# 3        Average orders
# 4        Average orders
# 5        Average orders
# 6        Average orders
# 7        Average orders
# 8        Average orders
# 9        Average orders

# %%
df.shape
# Out:
# (1000000, 16)

# %% [markdown]
# # grouping data

# %%
df.groupby('product_name')

# %% [markdown]
# # aggregating data

# %%
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean','min','max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # aggregating with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10          10   2968173       15            15                   1
# 11          11   1870022       15            17                   2
# 12          12   1911383       15            18                   2
# 13          13   2715276       15            21                   1
# 14          14    487368       15            22                   1
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0           0         Soda        77              7     9.0   both
# 1           1         Soda        77              7     9.0   both
# 2           1         Soda        77              7     9.0   both
# 3           1         Soda        77              7     9.0   both
# 4           1         Soda        77              7     9.0   both
# 5           1         Soda        77              7     9.0   both
# 6           1         Soda        77              7     9.0   both
# 7           1         Soda        77              7     9.0   both
# 8           1         Soda        77              7     9.0   both
# 9           1         Soda        77              7     9.0   both
# 10          0         Soda        77              7     9.0   both
# 11          1         Soda        77              7     9.0   both
# 12          1         Soda        77              7     9.0   both
# 13          1         Soda        77              7     9.0   both
# 14          1         Soda        77              7     9.0   both
#
#        busiest_day busiest_period_of_day  max_order
# 0   Regularly busy        Average orders         10
# 1     Slowest days        Average orders         10
# 2     Slowest days        Average orders         10
# 3     Slowest days        Average orders         10
# 4     Slowest days        Average orders         10
# 5   Regularly busy        Average orders         10
# 6     Busiest days        Average orders         10
# 7     Busiest days        Average orders         10
# 8     Busiest days        Average orders         10
# 9     Slowest days        Average orders         10
# 10    Busiest days        Average orders         22
# 11  Regularly busy        Average orders         22
# 12  Regularly busy        Average orders         22
# 13    Busiest days        Average orders         22
# 14    Busiest days           Most orders         22

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0            0   2539329        1             1                   2
# 1            1   2398795        1             2                   3
# 2            2    473747        1             3                   3
# 3            3   2254736        1             4                   4
# 4            4    431534        1             5                   4
# 5            5   3367565        1             6                   2
# 6            6    550135        1             7                   1
# 7            7   3108588        1             8                   1
# 8            8   2295261        1             9                   1
# 9            9   2550362        1            10                   4
# 10          10   2968173       15            15                   1
# 11          11   1870022       15            17                   2
# 12          12   1911383       15            18                   2
# 13          13   2715276       15            21                   1
# 14          14    487368       15            22                   1
# 15          15   2293453       19             2                   5
# 16          16   1973799       19             5                   6
# 17          17    532817       19             7                   4
# 18          18   1573906       21            10                   3
# 19          19   1593000       31            10                   3
# 20          20   2231262       31            17                   3
# 21          21   2580647       43             6                   4
# 22          22   2187180       43             9                   4
# 23          23   2497897       52             1                   1
# 24          24   1318871       52             2                   1
# 25          25   1261384       52             3                   1
# 26          26    580568       52             5                   2
# 27          27   2428073       52             7                   2
# 28          28    342306       52             9                   1
# 29          29   1520353       52            10                   2
# 30          30   2542086       52            11                   2
# 31          31    944694       52            12                   1
# 32          32   1268191       52            15                   2
# 33          33   1122089       52            17                   2
# 34          34   1498922       52            18                   2
# 35          35    180919       52            19                   3
# 36          36   2695875       52            21                   5
# 37          37   3205960       67             1                   3
# 38          38    970922       67             2                   1
# 39          39    596585       67             3                   1
# 40          40   2037087       67             4                   2
# 41          41   2474111       67             5                   3
# 42          42   1568481       67             6                   3
# 43          43   2048527       67             8                   2
# 44          44   2389031       67             9                   2
# 45          45   2378562       67            10                   1
# 46          46   1515698       67            11                   1
# 47          47   1928050       67            12                   2
# 48          48   1949274       67            13                   1
# 49          49    551869       67            14                   1
# 50          50    768572       67            16                   4
# 51          51    150528       67            18                   5
# 52          52     29758       67            19                   0
# 53          53   1558976       67            21                   1
# 54          54    863974       67            22                   1
# 55          55   2308399       67            23                   1
# 56          56   2759128       81             3                   1
# 57          57   1812985       81             5                   2
# 58          58   1889835       82             1                   3
# 59          59    499460       82             3                   5
# 60          60   2728456       82             4                   0
# 61          61   2653743       82             6                   4
# 62          62   1358880       82             9                   1
# 63          63    343588       82            10                   2
# 64          64   3034663       82            15                   2
# 65          65    147262       82            18                   1
# 66          66   3144004       82            19                   2
# 67          67   2126069       98             3                   0
# 68          68   2210120       98             7                   5
# 69          69    681011       98             9                   3
# 70          70   2846344       98            11                   4
# 71          71    747431       98            12                   6
# 72          72   2383054       98            13                   4
# 73          73   1993729       98            14                   5
# 74          74   1403849      109             3                   3
# 75          75    520620      120             1                   3
# 76          76   3273029      120             3                   2
# 77          77   1861943      185             2                   1
# 78          78   2040988      195             1                   1
# 79          79   1680569      195             8                   1
# 80          80    276171      195            19                   5
# 81          81   2744976      195            22                   5
# 82          82   2781919      195            25                   1
# 83          83   1738718      195            31                   2
# 84          84   3058369      195            34                   3
# 85          85   1485596      195            37                   2
# 86          86    417035      195            40                   3
# 87          87   1615297      195            47                   5
# 88          88   1765587      195            52                   3
# 89          89    745908      195            57                   4
# 90          90   2505656      222            17                   2
# 91          91   3268370      222            38                   5
# 92          92   2016711      290             9                   5
# 93          93   2706088      290            28                   6
# 94          94   1952286      331             6                   5
# 95          95   3226575      360             1                   5
# 96          96   1469869      377             3                   5
# 97          97   1927023      387             2                   4
# 98          98    858092      420             4                   1
# 99          99    119314      420             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# 5                   7                    19.0         196                  1
# 6                   9                    20.0         196                  1
# 7                  14                    14.0         196                  2
# 8                  16                     0.0         196                  4
# 9                   8                    30.0         196                  1
# 10                  9                     7.0         196                  2
# 11                 16                     8.0         196                  6
# 12                 11                     7.0         196                  1
# 13                  9                     7.0         196                  1
# 14                 10                    14.0         196                  1
# 15                 14                     6.0         196                  3
# 16                 12                     8.0         196                 15
# 17                 17                     6.0         196                  1
# 18                 10                     6.0         196                  2
# 19                  8                     7.0         196                 17
# 20                 11                     8.0         196                 14
# 21                 16                     4.0         196                  9
# 22                 12                     3.0         196                  1
# 23                  9                     NaN         196                  4
# 24                 10                     7.0         196                  5
# 25                 10                     7.0         196                  3
# 26                 10                     8.0         196                  6
# 27                  7                     8.0         196                  5
# 28                 11                     7.0         196                  5
# 29                 10                     8.0         196                  4
# 30                  9                     7.0         196                  3
# 31                 16                     6.0         196                  7
# 32                 11                     8.0         196                  3
# 33                 10                     6.0         196                  4
# 34                 10                    14.0         196                  6
# 35                  8                     8.0         196                  4
# 36                 10                    30.0         196                  1
# 37                 11                     NaN         196                  1
# 38                 15                     5.0         196                  2
# 39                 13                     7.0         196                  2
# 40                  9                     8.0         196                  1
# 41                 14                     8.0         196                  2
# 42                 12                     7.0         196                  2
# 43                 11                     7.0         196                  1
# 44                 14                     7.0         196                  1
# 45                 10                     6.0         196                  1
# 46                 11                     7.0         196                  1
# 47                 12                     8.0         196                  1
# 48                 10                     6.0         196                  1
# 49                  9                     7.0         196                  1
# 50                 10                     9.0         196                  1
# 51                 16                     4.0         196                  1
# 52                 14                     9.0         196                  2
# 53                  9                     5.0         196                  2
# 54                 11                    14.0         196                  3
# 55                 14                    14.0         196                  1
# 56                  9                    14.0         196                  2
# 57                 20                    30.0         196                  1
# 58                 15                     NaN         196                  6
# 59                 10                     5.0         196                  2
# 60                 11                    16.0         196                  1
# 61                  9                    13.0         196                  5
# 62                 10                    30.0         196                  1
# 63                 11                     1.0         196                  1
# 64                 11                    12.0         196                  1
# 65                 13                     7.0         196                  1
# 66                 15                     8.0         196                  1
# 67                  9                    25.0         196                  7
# 68                 14                     5.0         196                  1
# 69                  9                    30.0         196                  1
# 70                 13                    15.0         196                  2
# 71                 13                    30.0         196                  4
# 72                 11                    30.0         196                  1
# 73                  8                     8.0         196                  2
# 74                 17                     9.0         196                  5
# 75                 11                     NaN         196                  2
# 76                  8                    19.0         196                  2
# 77                 12                    25.0         196                 10
# 78                 14                     NaN         196                  2
# 79                  9                     4.0         196                  2
# 80                 11                     3.0         196                  2
# 81                 10                     7.0         196                  2
# 82                 14                     4.0         196                  1
# 83                  8                     4.0         196                  2
# 84                 10                     6.0         196                  2
# 85                 15                     0.0         196                  2
# 86                 16                     2.0         196                  2
# 87                 10                     2.0         196                  2
# 88                 12                     2.0         196                  3
# 89                 11                     3.0         196                  3
# 90                 12                     1.0         196                  2
# 91                 15                     1.0         196                  6
# 92                 19                     6.0         196                  8
# 93                 10                     7.0         196                 16
# 94                 16                    30.0         196                  8
# 95                 12                     NaN         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0           0         Soda        77              7     9.0   both
# 1           1         Soda        77              7     9.0   both
# 2           1         Soda        77              7     9.0   both
# 3           1         Soda        77              7     9.0   both
# 4           1         Soda        77              7     9.0   both
# 5           1         Soda        77              7     9.0   both
# 6           1         Soda        77              7     9.0   both
# 7           1         Soda        77              7     9.0   both
# 8           1         Soda        77              7     9.0   both
# 9           1         Soda        77              7     9.0   both
# 10          0         Soda        77              7     9.0   both
# 11          1         Soda        77              7     9.0   both
# 12          1         Soda        77              7     9.0   both
# 13          1         Soda        77              7     9.0   both
# 14          1         Soda        77              7     9.0   both
# 15          0         Soda        77              7     9.0   both
# 16          1         Soda        77              7     9.0   both
# 17          1         Soda        77              7     9.0   both
# 18          0         Soda        77              7     9.0   both
# 19          0         Soda        77              7     9.0   both
# 20          1         Soda        77              7     9.0   both
# 21          0         Soda        77              7     9.0   both
# 22          1         Soda        77              7     9.0   both
# 23          0         Soda        77              7     9.0   both
# 24          1         Soda        77              7     9.0   both
# 25          1         Soda        77              7     9.0   both
# 26          1         Soda        77              7     9.0   both
# 27          1         Soda        77              7     9.0   both
# 28          1         Soda        77              7     9.0   both
# 29          1         Soda        77              7     9.0   both
# 30          1         Soda        77              7     9.0   both
# 31          1         Soda        77              7     9.0   both
# 32          1         Soda        77              7     9.0   both
# 33          1         Soda        77              7     9.0   both
# 34          1         Soda        77              7     9.0   both
# 35          1         Soda        77              7     9.0   both
# 36          1         Soda        77              7     9.0   both
# 37          0         Soda        77              7     9.0   both
# 38          1         Soda        77              7     9.0   both
# 39          1         Soda        77              7     9.0   both
# 40          1         Soda        77              7     9.0   both
# 41          1         Soda        77              7     9.0   both
# 42          1         Soda        77              7     9.0   both
# 43          1         Soda        77              7     9.0   both
# 44          1         Soda        77              7     9.0   both
# 45          1         Soda        77              7     9.0   both
# 46          1         Soda        77              7     9.0   both
# 47          1         Soda        77              7     9.0   both
# 48          1         Soda        77              7     9.0   both
# 49          1         Soda        77              7     9.0   both
# 50          1         Soda        77              7     9.0   both
# 51          1         Soda        77              7     9.0   both
# 52          1         Soda        77              7     9.0   both
# 53          1         Soda        77              7     9.0   both
# 54          1         Soda        77              7     9.0   both
# 55          1         Soda        77              7     9.0   both
# 56          0         Soda        77              7     9.0   both
# 57          1         Soda        77              7     9.0   both
# 58          0         Soda        77              7     9.0   both
# 59          1         Soda        77              7     9.0   both
# 60          1         Soda        77              7     9.0   both
# 61          1         Soda        77              7     9.0   both
# 62          1         Soda        77              7     9.0   both
# 63          1         Soda        77              7     9.0   both
# 64          1         Soda        77              7     9.0   both
# 65          1         Soda        77              7     9.0   both
# 66          1         Soda        77              7     9.0   both
# 67          0         Soda        77              7     9.0   both
# 68          1         Soda        77              7     9.0   both
# 69          1         Soda        77              7     9.0   both
# 70          1         Soda        77              7     9.0   both
# 71          1         Soda        77              7     9.0   both
# 72          1         Soda        77              7     9.0   both
# 73          1         Soda        77              7     9.0   both
# 74          0         Soda        77              7     9.0   both
# 75          0         Soda        77              7     9.0   both
# 76          1         Soda        77              7     9.0   both
# 77          0         Soda        77              7     9.0   both
# 78          0         Soda        77              7     9.0   both
# 79          1         Soda        77              7     9.0   both
# 80          1         Soda        77              7     9.0   both
# 81          1         Soda        77              7     9.0   both
# 82          1         Soda        77              7     9.0   both
# 83          1         Soda        77              7     9.0   both
# 84          1         Soda        77              7     9.0   both
# 85          1         Soda        77              7     9.0   both
# 86          1         Soda        77              7     9.0   both
# 87          1         Soda        77              7     9.0   both
# 88          1         Soda        77              7     9.0   both
# 89          1         Soda        77              7     9.0   both
# 90          0         Soda        77              7     9.0   both
# 91          1         Soda        77              7     9.0   both
# 92          0         Soda        77              7     9.0   both
# 93          1         Soda        77              7     9.0   both
# 94          0         Soda        77              7     9.0   both
# 95          0         Soda        77              7     9.0   both
# 96          0         Soda        77              7     9.0   both
# 97          0         Soda        77              7     9.0   both
# 98          0         Soda        77              7     9.0   both
# 99          1         Soda        77              7     9.0   both
#
#        busiest_day busiest_period_of_day  max_order
# 0   Regularly busy        Average orders         10
# 1     Slowest days        Average orders         10
# 2     Slowest days        Average orders         10
# 3     Slowest days        Average orders         10
# 4     Slowest days        Average orders         10
# 5   Regularly busy        Average orders         10
# 6     Busiest days        Average orders         10
# 7     Busiest days        Average orders         10
# 8     Busiest days        Average orders         10
# 9     Slowest days        Average orders         10
# 10    Busiest days        Average orders         22
# 11  Regularly busy        Average orders         22
# 12  Regularly busy        Average orders         22
# 13    Busiest days        Average orders         22
# 14    Busiest days           Most orders         22
# 15  Regularly busy        Average orders          9
# 16  Regularly busy        Average orders          9
# 17    Slowest days        Average orders          9
# 18    Slowest days           Most orders         33
# 19    Slowest days        Average orders         20
# 20    Slowest days        Average orders         20
# 21    Slowest days        Average orders         11
# 22    Slowest days        Average orders         11
# 23    Busiest days        Average orders         27
# 24    Busiest days           Most orders         27
# 25    Busiest days           Most orders         27
# 26  Regularly busy           Most orders         27
# 27  Regularly busy        Average orders         27
# 28    Busiest days        Average orders         27
# 29  Regularly busy           Most orders         27
# 30  Regularly busy        Average orders         27
# 31    Busiest days        Average orders         27
# 32  Regularly busy        Average orders         27
# 33  Regularly busy           Most orders         27
# 34  Regularly busy           Most orders         27
# 35    Slowest days        Average orders         27
# 36  Regularly busy           Most orders         27
# 37    Slowest days        Average orders         24
# 38    Busiest days        Average orders         24
# 39    Busiest days        Average orders         24
# 40  Regularly busy        Average orders         24
# 41    Slowest days        Average orders         24
# 42    Slowest days        Average orders         24
# 43  Regularly busy        Average orders         24
# 44  Regularly busy        Average orders         24
# 45    Busiest days           Most orders         24
# 46    Busiest days        Average orders         24
# 47  Regularly busy        Average orders         24
# 48    Busiest days           Most orders         24
# 49    Busiest days        Average orders         24
# 50    Slowest days           Most orders         24
# 51  Regularly busy        Average orders         24
# 52    Busiest days        Average orders         24
# 53    Busiest days        Average orders         24
# 54    Busiest days        Average orders         24
# 55    Busiest days        Average orders         24
# 56    Busiest days        Average orders          7
# 57  Regularly busy        Average orders          7
# 58    Slowest days        Average orders         19
# 59  Regularly busy           Most orders         19
# 60    Busiest days        Average orders         19
# 61    Slowest days        Average orders         19
# 62    Busiest days           Most orders         19
# 63  Regularly busy        Average orders         19
# 64  Regularly busy        Average orders         19
# 65    Busiest days        Average orders         19
# 66  Regularly busy        Average orders         19
# 67    Busiest days        Average orders         14
# 68  Regularly busy        Average orders         14
# 69    Slowest days        Average orders         14
# 70    Slowest days        Average orders         14
# 71  Regularly busy        Average orders         14
# 72    Slowest days        Average orders         14
# 73  Regularly busy        Average orders         14
# 74    Slowest days        Average orders          6
# 75    Slowest days        Average orders          3
# 76  Regularly busy        Average orders          3
# 77    Busiest days        Average orders          6
# 78    Busiest days        Average orders         58
# 79    Busiest days        Average orders         58
# 80  Regularly busy        Average orders         58
# 81  Regularly busy           Most orders         58
# 82    Busiest days        Average orders         58
# 83  Regularly busy        Average orders         58
# 84    Slowest days           Most orders         58
# 85  Regularly busy        Average orders         58
# 86    Slowest days        Average orders         58
# 87  Regularly busy           Most orders         58
# 88    Slowest days        Average orders         58
# 89    Slowest days        Average orders         58
# 90  Regularly busy        Average orders         70
# 91  Regularly busy        Average orders         70
# 92  Regularly busy        Average orders         51
# 93  Regularly busy           Most orders         51
# 94  Regularly busy        Average orders          8
# 95  Regularly busy        Average orders          3
# 96  Regularly busy        Average orders          3
# 97    Slowest days           Most orders          8
# 98    Busiest days        Average orders         22
# 99    Slowest days        Average orders         22

# %% [markdown]
# # deriving with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %%
ords_prods_merge.head(10)
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           1   2398795        1             2                   3
# 2           2    473747        1             3                   3
# 3           3   2254736        1             4                   4
# 4           4    431534        1             5                   4
# 5           5   3367565        1             6                   2
# 6           6    550135        1             7                   1
# 7           7   3108588        1             8                   1
# 8           8   2295261        1             9                   1
# 9           9   2550362        1            10                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
# 5                  7                    19.0         196                  1
# 6                  9                    20.0         196                  1
# 7                 14                    14.0         196                  2
# 8                 16                     0.0         196                  4
# 9                  8                    30.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
# 5          1         Soda        77              7     9.0   both
# 6          1         Soda        77              7     9.0   both
# 7          1         Soda        77              7     9.0   both
# 8          1         Soda        77              7     9.0   both
# 9          1         Soda        77              7     9.0   both
#
#       busiest_day busiest_period_of_day  max_order  loyalty_flag
# 0  Regularly busy        Average orders         10  New customer
# 1    Slowest days        Average orders         10  New customer
# 2    Slowest days        Average orders         10  New customer
# 3    Slowest days        Average orders         10  New customer
# 4    Slowest days        Average orders         10  New customer
# 5  Regularly busy        Average orders         10  New customer
# 6    Busiest days        Average orders         10  New customer
# 7    Busiest days        Average orders         10  New customer
# 8    Busiest days        Average orders         10  New customer
# 9    Slowest days        Average orders         10  New customer

# %%
ords_prods_merge = ords_prods_merge.drop(columns = '_merge')

# %%
ords_prods_merge = ords_prods_merge.drop(columns = 'Unnamed: 0')

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices     busiest_day  \
# 0         Soda        77              7     9.0  Regularly busy
# 1         Soda        77              7     9.0    Slowest days
# 2         Soda        77              7     9.0    Slowest days
# 3         Soda        77              7     9.0    Slowest days
# 4         Soda        77              7     9.0    Slowest days
# 5         Soda        77              7     9.0  Regularly busy
# 6         Soda        77              7     9.0    Busiest days
# 7         Soda        77              7     9.0    Busiest days
# 8         Soda        77              7     9.0    Busiest days
# 9         Soda        77              7     9.0    Slowest days
#
#   busiest_period_of_day  max_order  loyalty_flag
# 0        Average orders         10  New customer
# 1        Average orders         10  New customer
# 2        Average orders         10  New customer
# 3        Average orders         10  New customer
# 4        Average orders         10  New customer
# 5        Average orders         10  New customer
# 6        Average orders         10  New customer
# 7        Average orders         10  New customer
# 8        Average orders         10  New customer
# 9        Average orders         10  New customer

# %% [markdown]
# # additional cleaning

# %%
# find prices over 100

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 10030345    912404       17            12                   2
# 10030346    603376       17            22                   6
# 10030347   3264360      135             2                   2
# 10030348    892534      135             3                   0
# 10030349    229704      342             8                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 10030345                 14                     5.0       21553
# 10030346                 16                     4.0       21553
# 10030347                 21                    13.0       21553
# 10030348                  8                    12.0       21553
# 10030349                 19                    30.0       21553
# ...                     ...                     ...         ...
# 29166209                  8                     4.0       33664
# 29166210                  9                     2.0       33664
# 29166211                 15                     8.0       33664
# 29166212                 20                     4.0       33664
# 29166213                 11                     4.0       33664
#
#           add_to_cart_order  reordered                      product_name  ...  \
# 10030345                  5          0  Lowfat 2% Milkfat Cottage Cheese  ...
# 10030346                  3          1  Lowfat 2% Milkfat Cottage Cheese  ...
# 10030347                  6          0  Lowfat 2% Milkfat Cottage Cheese  ...
# 10030348                  3          1  Lowfat 2% Milkfat Cottage Cheese  ...
# 10030349                  9          0  Lowfat 2% Milkfat Cottage Cheese  ...
# ...                     ...        ...                               ...  ...
# 29166209                  1          0             2 % Reduced Fat  Milk  ...
# 29166210                  1          1             2 % Reduced Fat  Milk  ...
# 29166211                 25          0             2 % Reduced Fat  Milk  ...
# 29166212                  8          0             2 % Reduced Fat  Milk  ...
# 29166213                 23          1             2 % Reduced Fat  Milk  ...
#
#           department_id   prices     busiest_day busiest_period_of_day  \
# 10030345             16  14900.0  Regularly busy        Average orders
# 10030346             16  14900.0  Regularly busy        Average orders
# 10030347             16  14900.0  Regularly busy        Average orders
# 10030348             16  14900.0    Busiest days        Average orders
# 10030349             16  14900.0    Busiest days        Average orders
# ...                 ...      ...             ...                   ...
# 29166209             16  99999.0    Busiest days        Average orders
# 29166210             16  99999.0    Busiest days        Average orders
# 29166211             16  99999.0    Slowest days        Average orders
# 29166212             16  99999.0    Slowest days        Average orders
# 29166213             16  99999.0    Busiest days        Average orders
#
#          max_order      loyalty_flag average_user_price  spending_flag  \
# 10030345        40  Regular customer         108.648299   High spender
# 10030346        40  Regular customer         108.648299   High spender
# 10030347         4      New customer        1154.792308   High spender
# 10030348         4      New customer        1154.792308   High spender
# 10030349        16  Regular customer         114.426619   High spender
# ...            ...               ...                ...            ...
# 29166209        39  Regular customer        1106.743956   High spender
# 29166210        39  Regular customer        1106.743956   High spender
# 29166211        15  Regular customer         451.153540   High spender
# 29166212        12  Regular customer        1178.381871   High spender
# 29166213        12  Regular customer        1178.381871   High spender
#
#          order_frequency         frequency_flag
# 10030345             5.0      Frequent customer
# 10030346             5.0      Frequent customer
# 10030347            12.0       Regular customer
# 10030348            12.0       Regular customer
# 10030349            23.0  Non-frequent customer
# ...                  ...                    ...
# 29166209             4.0      Frequent customer
# 29166210             4.0      Frequent customer
# 29166211             5.0      Frequent customer
# 29166212            12.0       Regular customer
# 29166213            12.0       Regular customer
#
# [5127 rows x 21 columns]

# %%
# mark as missing

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0
